# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 1
# %aimport plotter
# %aimport
# Out:
# Concept list length: 400
# Modules to reload:
# plotter
#
# Modules to skip:

# %%
import plotter
from functools import partial as at

# %%
xaxis = "Starting weight distribution"
n, p, s = plotter.load(plotter.property_key("i"),
                       sample_data=at(plotter.sample_data, relative=0, concepts=plotter.all_concepts))

# %%
labels = ['1', 'geom5', 'd10', '6', '10', '20', '30', 'd60', '60',
          '100', 'd199', 'fpareto100', 'geom100', 'poisson100',
          '200', '400', '800']
set(n.keys()) - set(labels)
# Out:
# {'poisson5'}

# %%
plotter.plot_something(n, labels, xaxis, "Vocabulary size")

# %%
plotter.plot_something(p, labels, xaxis, "Polysemy count")

# %%
plotter.plot_something(s, labels, xaxis, "Synonym count")
